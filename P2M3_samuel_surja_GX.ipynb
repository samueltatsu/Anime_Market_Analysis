# %% [markdown]
# # Milestone 3 - Great Expectation

# %% [markdown]
# # Instantiate Data Context

# %%
# Create a data context

from great_expectations.data_context import FileDataContext

context = FileDataContext.create(project_root_dir='./')

# %% [markdown]
# # Connect to Data Source

# %%
# Give a name to a Datasource. This name must be unique between Datasources.
datasource_name = 'csv-data-feb'
datasource = context.sources.add_pandas(datasource_name)

# Give a name to a data asset
asset_name = 'anime-februari'
path_to_data = 'C:\FTDS\MS\p2-ftds012-hck-m3-samueltatsu\dags\P2M3_samuel_surja_data_clean.csv'
asset = datasource.add_csv_asset(asset_name, filepath_or_buffer=path_to_data)

# Build batch request
batch_request = asset.build_batch_request()

# %% [markdown]
# # Create Expectation Suite

# %%
# Creat an expectation suite
expectation_suite_name = 'expectation-anime-dataset'
context.add_or_update_expectation_suite(expectation_suite_name)

# Create a validator using above expectation suite
validator = context.get_validator(
    batch_request = batch_request,
    expectation_suite_name = expectation_suite_name
)

# Check the validator
validator.head()
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
#    anime_id                             name  score  \
# 0         1                     Cowboy Bebop   8.78
# 1         5  Cowboy Bebop: Tengoku no Tobira   8.39
# 2         6                           Trigun   8.24
# 3         7               Witch Hunter Robin   7.27
# 4         8                   Bouken Ou Beet   6.98
#
#                                               genres            english_name  \
# 0    Action, Adventure, Comedy, Drama, Sci-Fi, Space            Cowboy Bebop
# 1              Action, Drama, Mystery, Sci-Fi, Space  Cowboy Bebop:The Movie
# 2  Action, Sci-Fi, Adventure, Comedy, Drama, Shounen                  Trigun
# 3  Action, Mystery, Police, Supernatural, Drama, ...      Witch Hunter Robin
# 4          Adventure, Fantasy, Shounen, Supernatural  Beet the Vandel Buster
#
#                       japanese_name  \
# 0                         カウボーイビバップ
# 1                    カウボーイビバップ 天国の扉
# 2                             トライガン
# 3  Witch Hunter ROBIN (ウイッチハンターロビン)
# 4                            冒険王ビィト
#
#                                             synopsis   type  episodes  \
# 0  In the year 2071, humanity has colonized sever...     TV        26
# 1  other day, another bounty—such is the life of ...  Movie         1
# 2  Vash the Stampede is the man with a $$60,000,0...     TV        26
# 3  ches are individuals with special powers like ...     TV        26
# 4  It is the dark century and the people are suff...     TV        52
#
#                           aired  ... duration_sec_per_ep  \
# 0   Apr 3, 1998 to Apr 24, 1999  ...                1440
# 1                   Sep 1, 2001  ...                3660
# 2   Apr 1, 1998 to Sep 30, 1998  ...                1440
# 3   Jul 2, 2002 to Dec 24, 2002  ...                1500
# 4  Sep 30, 2004 to Sep 29, 2005  ...                1380
#
#                            rating ranked popularity  members  favorites  \
# 0  R - 17+ (violence & profanity)     28         39  1251960      61971
# 1  R - 17+ (violence & profanity)    159        518   273145       1174
# 2       PG-13 - Teens 13 or older    266        201   558913      12944
# 3       PG-13 - Teens 13 or older   2481       1467    94683        587
# 4                   PG - Children   3710       4369    13224         18
#
#   watching  completed  on_hold  dropped
# 0   105808     718161    71513    26678
# 1     4143     208333     1935      770
# 2    29113     343492    25465    13925
# 3     4300      46165     5121     5378
# 4      642       7314      766     1108
#
# [5 rows x 25 columns]

# %% [markdown]
# # Expectations

# %% [markdown]
# **1. `anime_id` must be unique**

# %%
validator.expect_column_values_to_be_unique('anime_id')
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 14952,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# **2. `score` must be between 0 and 10**

# %% [markdown]
# Score or rating is supposed to be between 0.00 and 10.00. Any value not within that range is invalid.

# %%
validator.expect_column_values_to_be_between(
    column='score', min_value=0, max_value=10
)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 14952,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# **3. `type` must be in set ['TV', 'Movie', 'OVA', 'Special', 'ONA', 'Music', 'Unknown']**

# %% [markdown]
# Anime are widely categorized into 5 types: TV, Movie, OVA, Special, ONA. There's a new category with the rising popularity of Music genre. Then we include 'Unknown' for the possibly not yet categorized anime title.

# %%
validator.expect_column_values_to_be_in_set(
    column='type', 
    value_set=['TV', 'Movie', 'OVA', 'Special', 'ONA', 'Music', 'Unknown']
)
# Out:
# Calculating Metrics:   0%|          | 0/8 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 14952,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# **4. `episodes` must be integer type**

# %% [markdown]
# Functionally, episodes should have a discrete numerical value.

# %%
validator.expect_column_values_to_be_in_type_list('episodes', ['int64'])
# Out:
# Calculating Metrics:   0%|          | 0/1 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "observed_value": "int64"
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# **5. At least 90% entry must have unique `japanese_name`**

# %% [markdown]
# Anime industry is dominated by japanese studios, producers, companies, etc. We can expect most anime titles have an original japanese name.

# %%
validator.expect_column_proportion_of_unique_values_to_be_between(
    column='japanese_name',
    min_value=0.9,  # Expect at least 90% entry have japanese title
    max_value=1,  # At most all entry have unique japanese title
)
# Out:
# Calculating Metrics:   0%|          | 0/7 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "observed_value": 0.9481005885500268
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# **6. `synopsis` must be less than 6000 characters**

# %% [markdown]
# The maximum number of characters allowed to write a synopsis is 6000 characters. We want to make sure our data is valid and follows that guideline.

# %%
validator.expect_column_value_lengths_to_be_between(
    column='synopsis',
    min_value=None, # no minimum length requirement
    max_value=6000, # max length allowed for synopsis
)
# Out:
# Calculating Metrics:   0%|          | 0/9 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "element_count": 14952,
#     "unexpected_count": 0,
#     "unexpected_percent": 0.0,
#     "partial_unexpected_list": [],
#     "missing_count": 0,
#     "missing_percent": 0.0,
#     "unexpected_percent_total": 0.0,
#     "unexpected_percent_nonmissing": 0.0
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# **7. `studios` column should contain top 5 studios**

# %% [markdown]
# Toei Animation, Sunrise, J.C.Staff, Madhouse, TMS Entertainment. These 5 studios are top contributors with most anime titles released. We want to make sure our data include these 5 no matter what.

# %%
validator.expect_column_distinct_values_to_contain_set(
    column='studios',
    value_set=['Toei Animation', 'Sunrise', 'J.C.Staff', 'Madhouse', 'TMS Entertainment']
)
# Out:
# Calculating Metrics:   0%|          | 0/4 [00:00<?, ?it/s]
# {
#   "success": true,
#   "result": {
#     "observed_value": [
#       "10Gauge",
#       "10Gauge, Studio DURIAN",
#       "2:10 AM Animation",
#       "8bit",
#       "A-1 Pictures",
#       "A-1 Pictures, Bridge",
#       "A-1 Pictures, Bridge, CloverWorks",
#       "A-1 Pictures, Lapin Track",
#       "A-1 Pictures, Ordet",
#       "A-1 Pictures, TROYCA",
#       "A-1 Pictures, Trigger, CloverWorks",
#       "A-Line",
#       "A-Real",
#       "A.C.G.T.",
#       "ACC Production",
#       "AIC",
#       "AIC ASTA",
#       "AIC Build",
#       "AIC Classic",
#       "AIC Frontier",
#       "AIC PLUS+",
#       "AIC Spirits",
#       "AIC Spirits, Asread",
#       "AIC Spirits, BeSTACK",
#       "AIC Spirits, Digital Frontier",
#       "AIC Spirits, Group TAC",
#       "AIC Takarazuka",
#       "AIC, APPP",
#       "AIC, Artmic",
#       "AIC, Artmic, Darts",
#       "AIC, Artmic, animate Film",
#       "AIC, Darts",
#       "AIC, Magic Bus, Ashi Production",
#       "AIC, Remic",
#       "AIC, Studio Hakk",
#       "AIC, Studio Kyuuma",
#       "AIC, animate Film",
#       "APPP",
#       "AQUA ARIS",
#       "ASK Animation Studio",
#       "AT-2",
#       "AXsiZ",
#       "Academy Productions",
#       "Acca effe, Giga Production",
#       "Actas",
#       "Actas, Bee Media",
#       "Actas, Brain's Base",
#       "Actas, Production Reed",
#       "Actas, Studio 3Hz",
#       "Actas, SynergySP",
#       "Actas, TMS Entertainment",
#       "Agent 21",
#       "Ajia-Do",
#       "Ajia-Do, Bandai Namco Pictures",
#       "Ajia-Do, Group TAC",
#       "Ajia-Do, Studio Deen",
#       "Ajia-Do, TMS Entertainment",
#       "Akatsuki",
#       "Albacrow",
#       "An DerCen",
#       "Anima",
#       "Anima&Co.",
#       "Anima, Dynamo Pictures",
#       "Anima, ILCA",
#       "Animaruya",
#       "Animation 21",
#       "Animation Planet",
#       "Animation Staff Room",
#       "Anime Antenna Iinkai",
#       "Anime R",
#       "Anime R, Aubec",
#       "Annapuru",
#       "Anpro",
#       "Anpro, teamKG",
#       "Arcs Create",
#       "Arcturus",
#       "Ark",
#       "Arms",
#       "Arms, Asread",
#       "Arms, Studio Kikan",
#       "Arms, TNK",
#       "Artland",
#       "Artland, AIC, Artmic",
#       "Artland, Hoods Entertainment",
#       "Artland, Madhouse",
#       "Artland, Magic Bus",
#       "Artland, Nippon Animation",
#       "Artland, TNK",
#       "Artland, Tatsunoko Production",
#       "Artmic",
#       "Artmic, animate Film",
#       "Arvo Animation",
#       "Asahi Production",
#       "Asahi Production, Rising Force",
#       "Asahi Production, Shochiku Animation Institute",
#       "Asahi Production, Success Corp.",
#       "Asatsu DK, Sunrise Beyond",
#       "Ascension",
#       "Ascension, Creators in Pack, Zero-G",
#       "Ashi Production",
#       "Asread",
#       "Asread, Tear Studio",
#       "Asread, White Fox",
#       "Asura Film",
#       "Aubec",
#       "Automatic Flowers Studio",
#       "Avex Pictures, production doA",
#       "Azeta Pictures",
#       "B&T",
#       "B.CMAY PICTURES",
#       "B.CMAY PICTURES, Colored-Pencil Animation Design",
#       "BOOTLEG",
#       "BUILD DREAM",
#       "BYMENT",
#       "Bakken Record",
#       "Bandai Namco Pictures",
#       "Barnum Studio, Project No.9",
#       "Barnum Studio, Project No.9, Studio Blanc",
#       "Barnum Studio, SILVER LINK., Connect",
#       "Bee Media",
#       "Bee Media, 81 Produce",
#       "Bee Media, Code",
#       "Bee Media, Studio Signal",
#       "Bee Train",
#       "Bee Train, Cookie Jar Entertainment",
#       "Bee Train, Production I.G, Madhouse, Studio 4\u00b0C",
#       "Bee Train, Xebec",
#       "Beijing Rocen Digital",
#       "Bibury Animation Studios",
#       "Big Bang",
#       "BigFireBird Animation",
#       "Blade",
#       "Blade, Thundray",
#       "Blue Cat",
#       "Bones",
#       "Bones, Kinema Citrus",
#       "Bones, Nomad",
#       "Bones, Orange",
#       "Bones, Production I.G, Studio 4\u00b0C, Toei Animation",
#       "Bones, Production Reed",
#       "Bones, Sanrio",
#       "Bones, Sunrise",
#       "Bones, Telecom Animation Film",
#       "Bouncy",
#       "Boyan Pictures",
#       "Brain's Base",
#       "Brain's Base, Marvy Jack",
#       "Brain's Base, Platinum Vision",
#       "Brain's Base, Shogakukan Music & Digital Entertainment",
#       "Brain's Base, Studio A-CAT",
#       "BreakBottle",
#       "Bridge",
#       "Bridge, Husio Studio",
#       "Brio Animation",
#       "Buemon",
#       "C-Station",
#       "C2C",
#       "C2C, Lay-duce",
#       "CG Year",
#       "CLAP",
#       "CUCURI, Digital Network Animation",
#       "Calf Studio",
#       "Chaos Project",
#       "Chaos Project, GANSIS",
#       "Charaction",
#       "Children's Playground Entertainment",
#       "Chippai",
#       "Chiptune",
#       "ChuChu",
#       "Circle Tribute",
#       "CloverWorks",
#       "CoMix Wave Films",
#       "CoMix Wave Films, FOREST Hunting One",
#       "Coastline Animation Studio",
#       "Collaboration Works",
#       "Composition Inc.",
#       "Congzhuo Animation",
#       "Connect",
#       "Craftar Studios",
#       "Creators Dot Com",
#       "Creators in Pack",
#       "Creators in Pack, LEVELS",
#       "Creators in Pack, Namu Animation",
#       "Creators in Pack, Saetta",
#       "Creators in Pack, Studio Lings",
#       "Creatures Inc.",
#       "CyberConnect2",
#       "Cyclone Graphics",
#       "CygamesPictures",
#       "D & D Pictures",
#       "D.A.S.T.",
#       "DAX Production",
#       "DLE",
#       "DMM pictures",
#       "DR Movie",
#       "Daewon Media",
#       "Dai-Ichi Douga",
#       "Dai-Ichi Douga, Dongyang Animation",
#       "Dancing CG Studio",
#       "DandeLion Animation Studio",
#       "Darts",
#       "Daume",
#       "David Production",
#       "Decovocal",
#       "Digital Frontier",
#       "Digital Media Lab",
#       "Digital Network Animation",
#       "Diomed\u00e9a",
#       "Diomed\u00e9a, Studio Blanc",
#       "Directions",
#       "Djinn Power",
#       "Doga Kobo",
#       "Doga Kobo, Orange",
#       "Dongwoo A&E",
#       "Drive",
#       "Durufix",
#       "Dwango, LIDENFILMS",
#       "Dynamic Planning",
#       "Dynamo Pictures",
#       "E&G Films",
#       "EDGE",
#       "EKACHI EPILKA",
#       "EMT Squared",
#       "ENGI",
#       "Echo",
#       "Echoes",
#       "Egg",
#       "Eiken",
#       "Eiken, Magic Bus",
#       "Eiken, Studio Live",
#       "Eiken, TYO Animations",
#       "Ekura Animal",
#       "ElectromagneticWave",
#       "Emon, Blade",
#       "Encourage Films",
#       "Enishiya",
#       "Enishiya, FILMONY",
#       "Enishiya, Toho Interactive Animation",
#       "Enoki Films, Dai Nippon Printing",
#       "Ether Kitten",
#       "Ez\u03ccla",
#       "Fanworks",
#       "Fanworks, Imagineer",
#       "Fanworks, Tomovies",
#       "Felix Film",
#       "Fifth Avenue",
#       "Filmlink International",
#       "Flat Studio",
#       "Flavors Soft",
#       "Front Line",
#       "Front Line, Studio G-1Neo",
#       "Fuji TV",
#       "Future Planet, Beijing Huihuang Animation Company",
#       "G&G Entertainment",
#       "G-Lam",
#       "G-Lam, Studio CA",
#       "G-angle",
#       "GARDEN LODGE",
#       "GEEK TOYS",
#       "GEN Productions",
#       "GRIZZLY",
#       "Gaina",
#       "Gainax",
#       "Gainax Kyoto",
#       "Gainax, Asahi Production",
#       "Gainax, Gaina",
#       "Gainax, Group TAC",
#       "Gainax, J.C.Staff",
#       "Gainax, Madhouse",
#       "Gainax, Magic Bus",
#       "Gainax, Production I.G",
#       "Gainax, Shaft",
#       "Gainax, Studio 4\u00b0C",
#       "Gainax, Studio Deen",
#       "Gainax, Tatsunoko Production",
#       "Gainax, Toei Animation",
#       "Gainax, feel.",
#       "Gakken Eigakyoku",
#       "Gallop",
#       "Gallop, Group TAC, Studio Junio",
#       "Gallop, Studio Comet",
#       "Gallop, Studio Deen",
#       "Gallop, TMS Entertainment",
#       "Gathering",
#       "Gathering, Asahi Production",
#       "Gathering, Lesprit",
#       "Genco, Radix",
#       "Genco, Triangle Staff",
#       "Geno Studio",
#       "Ginga Ya",
#       "GoHands",
#       "Gold Bear",
#       "Gonzo",
#       "Gonzo, AIC",
#       "Gonzo, Asread",
#       "Gonzo, DLE",
#       "Gonzo, DandeLion Animation Studio",
#       "Gonzo, Gainax, Production I.G, Madhouse, Studio 4\u00b0C, Satelight, CoMix Wave Films",
#       "Gonzo, Hoods Entertainment",
#       "Gonzo, LandQ studios",
#       "Gonzo, Palm Studio",
#       "Gonzo, Picture Magic",
#       "Gonzo, Production I.G",
#       "Gonzo, Satelight",
#       "Gonzo, Seven",
#       "Gonzo, Stingray",
#       "Gonzo, Studio Kai",
#       "Gonzo, ufotable",
#       "Gosay Studio",
#       "Graphinica",
#       "Green Bunny",
#       "Green Monster Team",
#       "Green Monster Team, BigFireBird Animation",
#       "Grom, Aurum Production",
#       "Group TAC",
#       "Group TAC, Amuse",
#       "Group TAC, Animaruya",
#       "Group TAC, G&G Entertainment",
#       "Group TAC, Ginga Ya",
#       "Group TAC, Japan Vistec",
#       "Group TAC, Studio Junio",
#       "Group TAC, View Works",
#       "Grouper Productions, Animation Staff Room",
#       "Guton Animation Studio",
#       "HOTZIPANG",
#       "HS Pictures Studio",
#       "Hal Film Maker",
#       "Hal Film Maker, Nomad",
#       "Hal Film Maker, TYO Animations",
#       "Haoliners Animation League",
#       "Haoliners Animation League, Garden Culture",
#       "Haoliners Animation League, Pb Animation Co. Ltd.",
#       "Haoliners Animation League, Studio LAN",
#       "HeART-BIT",
#       "Heewon Entertainment, NHK Enterprises",
#       "Himajin Planning",
#       "Hoods Drifters Studio",
#       "Hoods Entertainment",
#       "Hoods Entertainment, Felix Film",
#       "Hoods Entertainment, Production IMS",
#       "Hoods Entertainment, teamKG",
#       "Hotline",
#       "ILCA",
#       "ILCA, DRAWIZ, Toho Interactive Animation",
#       "IMAGICA Lab.",
#       "Idea Factory",
#       "Image House",
#       "Imagin",
#       "Imagin, Studio Live",
#       "Imagineer",
#       "Indeprox",
#       "Irawias",
#       "Ishikawa Pro",
#       "Ishimori Entertainment",
#       "Iyasakadou Film",
#       "J.C.Staff",
#       "J.C.Staff, A.C.G.T.",
#       "J.C.Staff, Artland",
#       "J.C.Staff, Egg Firm",
#       "J.C.Staff, Kitty Films",
#       "J.C.Staff, Life Work",
#       "J.C.Staff, Nomad",
#       "J.C.Staff, Production I.G",
#       "J.C.Staff, Production Reed",
#       "J.C.Staff, SANZIGEN",
#       "J.C.Staff, Studio Ghibli",
#       "J.C.Staff, Tatsunoko Production",
#       "J.C.Staff, Toei Animation",
#       "J.C.Staff, animate Film",
#       "JCF",
#       "Japan Taps",
#       "Jinnis Animation Studios",
#       "Joker Films",
#       "Jumondo",
#       "Jumonji",
#       "KAGAYA Studio",
#       "KIZAWA Studio",
#       "KJJ Animation",
#       "KOO-KI",
#       "KSS",
#       "Kachidoki Studio",
#       "Kaeruotoko Shokai",
#       "Kamikaze Douga",
#       "Kamikaze Douga, Nishiki Studio",
#       "Kamikaze Douga, Space Neko Company",
#       "Kanaban Graphics",
#       "Kaname Productions",
#       "Kaname Productions, Idol",
#       "Karaku",
#       "Karasfilms",
#       "Kate Arrow",
#       "Kazami Gakuen Koushiki Douga-bu",
#       "Kazuki Production",
#       "Keica, The Monk Studios",
#       "Kenji Studio",
#       "Khara",
#       "Khara, CyberConnect2",
#       "Khara, Trigger, Studio Colorido",
#       "Kinema Citrus",
#       "Kinema Citrus, DR Movie",
#       "Kinema Citrus, EMT Squared",
#       "Kinema Citrus, IMAGICA Lab.",
#       "Kinema Citrus, Orange",
#       "Kinema Citrus, White Fox",
#       "Kitty Films",
#       "Knack Productions",
#       "Kokusai Eigasha",
#       "Kyoto Animation",
#       "Kyoto Animation, Animation Do",
#       "Kyoto Animation, Production I.G, Shin-Ei Animation",
#       "Kyoto Animation, Shin-Ei Animation",
#       "Kyoto Animation, Sunrise",
#       "Kyoto Animation, Tatsunoko Production",
#       "Kyotoma",
#       "Kyotoma, Office Nobu",
#       "LICO, Red Dog Culture House",
#       "LIDENFILMS",
#       "LIDENFILMS, Felix Film",
#       "LIDENFILMS, domerica",
#       "LMD",
#       "LX Animation Studio",
#       "LandQ studios",
#       "Larx Entertainment",
#       "Lay-duce",
#       "Lerche",
#       "Lerche, 10Gauge",
#       "Lesprit",
#       "Liberty Animation Studio",
#       "Lide",
#       "Life Work",
#       "Light Chaser Animation Studios",
#       "Lilix",
#       "Live2D Creative Studio",
#       "L\u00b2Studio",
#       "M.S.C",
#       "M.S.C, Studio Kai",
#       "MAPPA",
#       "MAPPA, Lapin Track",
#       "MAPPA, Studio VOLN",
#       "MASTER LIGHTS",
#       "MAT",
#       "MMDGP",
#       "MORIE Inc.",
#       "MS Pictures",
#       "Madhouse",
#       "Madhouse, Animation Staff Room",
#       "Madhouse, DLE",
#       "Madhouse, Group TAC",
#       "Madhouse, Imagin",
#       "Madhouse, MAPPA",
#       "Madhouse, Production Reed",
#       "Madhouse, Satelight, Graphinica",
#       "Madhouse, Studio 4\u00b0C",
#       "Madhouse, Studio Deen",
#       "Madhouse, Studio Deen, Magic Bus",
#       "Madhouse, Studio Fantasia",
#       "Madhouse, Studio Gokumi",
#       "Madhouse, TMS Entertainment",
#       "Madhouse, TNK",
#       "Madhouse, Tatsunoko Production",
#       "Madhouse, Telecom Animation Film",
#       "Madhouse, Tezuka Productions",
#       "Madhouse, Toei Animation",
#       "Madhouse, Tokyo Movie Shinsha",
#       "Madhouse, feel.",
#       "Magic Bus",
#       "Maho Film",
#       "Majin",
#       "Making Animation",
#       "Manglobe",
#       "Manglobe, Geno Studio",
#       "Maro Studio",
#       "Marvy Jack",
#       "Mary Jane",
#       "Marza Animation Planet",
#       "Maxilla",
#       "Media Bank",
#       "Mili Pictures",
#       "Milky Animation Label",
#       "Milky Animation Label, Studio Jam",
#       "Milky Cartoon",
#       "Milky Cartoon, LMD",
#       "Millepensee",
#       "Millepensee, GEMBA",
#       "Minakata Laboratory",
#       "Minami Machi Bugyousho",
#       "Mirai Film",
#       "Mokai Technology",
#       "Monster's Egg",
#       "MooGoo",
#       "Mook Animation",
#       "Mook Animation, Urban Product",
#       "Mook DLE",
#       "Moss Design Unit",
#       "Motion Magic",
#       "Mushi Production",
#       "NAZ",
#       "NAZ, Magia Doraglier",
#       "NHK",
#       "NHK Enterprises",
#       "Namu Animation",
#       "Natural High",
#       "Neft Film",
#       "Next Media Animation",
#       "Nexus",
#       "Nice Boat Animation",
#       "Nice Boat Animation, Samsara Animation Studio",
#       "Nippon Animation",
#       "Nippon Animation, Gallop",
#       "Nippon Animation, Gallop, TMS Entertainment, DLE",
#       "Nippon Animation, Production Reed",
#       "Nippon Animation, Shaft",
#       "Nippon Animation, Studio WHO",
#       "Nippon Animation, SynergySP, Shirogumi",
#       "Nippon Animation, Tatsunoko Production",
#       "Nippon Animation, Xebec",
#       "Nippon Ramayana Film Co.",
#       "Nomad",
#       "Nur",
#       "Nut",
#       "OLM",
#       "OLM Digital",
#       "OLM Digital, Signal.MD",
#       "OLM, AIC ASTA",
#       "OLM, OLM Digital",
#       "OLM, OLM Digital, Sprite Animation Studios",
#       "OLM, P.A. Works",
#       "OLM, P.I.C.S.",
#       "OLM, Pastel",
#       "OLM, Production Reed",
#       "OLM, Shin-Ei Animation",
#       "OLM, Sunrise Beyond",
#       "OLM, Wit Studio",
#       "ORENDA",
#       "OZ",
#       "October Media",
#       "Oddjob",
#       "Odolttogi",
#       "Office AO",
#       "Office DCI",
#       "Office Take Off",
#       "Office Takeout",
#       "Oh! Production",
#       "Okuruto Noboru",
#       "Onionskin",
#       "Opera House",
#       "Orange",
#       "Orange, Seven Arcs Pictures",
#       "Orange, Studio 3Hz",
#       "Ordet",
#       "Ordet, Encourage Films",
#       "Ordet, LIDENFILMS",
#       "Ordet, Millepensee",
#       "Ordet, SANZIGEN",
#       "Ordet, Studio Moriken",
#       "Ordet, W-Toon Studio",
#       "Original Force, Wan Wei Mao Donghua",
#       "Oxybot",
#       "Oz",
#       "P.A. Works",
#       "P.A. Works, Studio 3Hz",
#       "PERIMETRON",
#       "PONOS Corporation",
#       "PPM",
#       "PRA",
#       "Painting Dream",
#       "Palm Studio",
#       "Pancake",
#       "Panda Factory",
#       "Panda Factory, Studio PuYUKAI",
#       "Panmedia, Meruhensha",
#       "Passione",
#       "Passione, Creators in Pack",
#       "Pastel",
#       "Pb Animation Co. Ltd., Studio LAN",
#       "Peak Hunt",
#       "Phoenix Entertainment",
#       "Picograph",
#       "Picona",
#       "Picture Magic",
#       "Picture Magic, Rikuentai",
#       "Pie in the sky",
#       "Pierrot Plus",
#       "Piko Studio",
#       "Pine Jam",
#       "Pine Jam, CloverWorks",
#       "Pink Pineapple",
#       "Piso Studio",
#       "Planet",
#       "Platinum Vision",
#       "Plum",
#       "Plum, Magic Bus",
#       "Plus Heads, Studio Crocodile",
#       "PoRO",
#       "Pollyanna Graphics",
#       "Polygon Pictures",
#       "Polygon Pictures, W+K Tokyo, Welz Animation Studios",
#       "Poncotan",
#       "Pony Canyon",
#       "Pops Inc.",
#       "Primastea",
#       "PrimeTime",
#       "Production +h.",
#       "Production I.G",
#       "Production I.G, DLE",
#       "Production I.G, Drive",
#       "Production I.G, I.Gzwei",
#       "Production I.G, LandQ studios",
#       "Production I.G, M.S.C",
#       "Production I.G, Madhouse",
#       "Production I.G, Nihon Ad Systems",
#       "Production I.G, Nut, Revoroot",
#       "Production I.G, OLM",
#       "Production I.G, OLM, Signal.MD",
#       "Production I.G, Polygon Pictures",
#       "Production I.G, Production Reed",
#       "Production I.G, SANZIGEN",
#       "Production I.G, Signal.MD",
#       "Production I.G, Signal.MD, Production GoodBook",
#       "Production I.G, Sola Digital Arts",
#       "Production I.G, Studio 4\u00b0C, Shaft",
#       "Production I.G, Studio Deen",
#       "Production I.G, Tatsunoko Production",
#       "Production I.G, Trans Arts",
#       "Production I.G, Welz Animation Studios",
#       "Production I.G, Xebec",
#       "Production I.G, Xebec, I.Gzwei",
#       "Production I.G, Xebec, OLM",
#       "Production I.G, Zexcs",
#       "Production I.G, animate Film",
#       "Production IMS",
#       "Production IMS, Orange",
#       "Production Reed",
#       "Production Reed, Asahi Production",
#       "Production Reed, D.A.S.T., Studio 88",
#       "Project No.9",
#       "Project No.9, A-Real",
#       "Project No.9, Tri-Slash",
#       "Public & Basic",
#       "Public & Basic, Ripple Film",
#       "Puzzle Animation Studio Limited",
#       "Qianqi Animation",
#       "Qualia Animation",
#       "Qubic Pictures, CGCG Studio",
#       "Queen Bee",
#       "RAMS",
#       "RG Animation Studios",
#       "Rabbit Machine",
#       "Radix",
#       "Radix, Chaos Project",
#       "Radix, Marine Entertainment",
#       "Remic",
#       "Revoroot",
#       "Rikuentai",
#       "Rikuentai, Nikkatsu",
#       "Ripple Film",
#       "Ripromo",
#       "Rising Force",
#       "Robot Communications",
#       "Robot Communications, Imagica Imageworks",
#       "Rockwell Eyes",
#       "Romanov Films",
#       "Ruo Hong Culture",
#       "SANZIGEN",
#       "SANZIGEN, DMM.futureworks",
#       "SANZIGEN, LIDENFILMS",
#       "SBS TV Production",
#       "SELFISH",
#       "SILVER LINK.",
#       "SILVER LINK., Connect",
#       "SILVER LINK., Nexus",
#       "SILVER LINK., Studio Palette",
#       "SPEED",
#       "Saetta",
#       "Saigo no Shudan",
#       "Sakura Create",
#       "Sanrio",
#       "Satelight",
#       "Satelight, 8bit",
#       "Satelight, A-1 Pictures",
#       "Satelight, C2C",
#       "Satelight, Encourage Films",
#       "Satelight, Production Reed",
#       "Satelight, Yumeta Company",
#       "Satelight, ixtl",
#       "Schoolzone",
#       "Science SARU",
#       "Sega Interactive",
#       "Seven",
#       "Seven Arcs",
#       "Seven Arcs Pictures",
#       "Seven Arcs, Seven Arcs Pictures",
#       "Seven Stone Entertainment",
#       "Seven, GEEK TOYS",
#       "Shaft",
#       "Shaft, Brain's Base, Japan Vistec",
#       "Shaft, Knack Productions",
#       "Shaft, TNK",
#       "Shaft, Tatsunoko Production",
#       "Shanghai Animation Film Studio",
#       "Shanghai Foch Film Culture Investment",
#       "Shenying Animation",
#       "Shimogumi",
#       "Shin-Ei Animation",
#       "Shin-Ei Animation, DLE",
#       "Shin-Ei Animation, Lesprit",
#       "Shin-Ei Animation, domerica",
#       "Shinkuukan",
#       "Shirogumi",
#       "Shirogumi, EMT Squared",
#       "Shirogumi, Encourage Films",
#       "Shirogumi, Robot Communications",
#       "Shirogumi, Shin-Ei Animation",
#       "Shochiku Animation Institute",
#       "Shogakukan Music & Digital Entertainment",
#       "Shueisha",
#       "Shuka",
#       "Signal.MD",
#       "Signal.MD, Sublimation",
#       "Silver",
#       "Silver, Arvo Animation",
#       "Soeishinsha",
#       "Sola Digital Arts",
#       "Sotsu",
#       "Soyep",
#       "Sparkly Key Animation Studio",
#       "Sparky Animation",
#       "Speed Inc.",
#       "Spell Bound",
#       "Square Enix",
#       "Steve N' Steven",
#       "Steve N' Steven, Rockwell Eyes",
#       "Stingray",
#       "Strawberry Meets Pictures",
#       "Studio 1st",
#       "Studio 3Hz",
#       "Studio 4\u00b0C",
#       "Studio 4\u00b0C, Ankama Animations",
#       "Studio 4\u00b0C, Shirogumi",
#       "Studio 4\u00b0C, Sunrise",
#       "Studio 88",
#       "Studio 9 MAiami",
#       "Studio A-CAT",
#       "Studio Animal",
#       "Studio Arch Inc.",
#       "Studio Bind",
#       "Studio Binzo",
#       "Studio Blanc",
#       "Studio Bogey",
#       "Studio Bogey, Public & Basic",
#       "Studio Chizu",
#       "Studio Coa",
#       "Studio Colorido",
#       "Studio Colorido, FILMONY",
#       "Studio Comet",
#       "Studio Comet, KeyEast, REALTHING",
#       "Studio Comet, Studio Sign",
#       "Studio Comet, Zexcs",
#       "Studio Core",
#       "Studio Crocodile",
#       "Studio Dadashow",
#       "Studio Deen",
#       "Studio Deen, DAX Production",
#       "Studio Deen, Daume",
#       "Studio Deen, Kitty Films",
#       "Studio Deen, Marvy Jack",
#       "Studio Deen, Studio Hibari",
#       "Studio Deen, Studio Hibari, Production Reed",
#       "Studio Deen, Wit Studio",
#       "Studio Egg",
#       "Studio Eromatick",
#       "Studio Fantasia",
#       "Studio Fantasia, Amber Film Works",
#       "Studio Fantasia, Chaos Project",
#       "Studio Fantasia, Rabbit Gate",
#       "Studio Fantasia, animate Film",
#       "Studio Flad",
#       "Studio Flad, Wolfsbane",
#       "Studio Flag",
#       "Studio Flag, Studio Bogey",
#       "Studio G-1Neo",
#       "Studio Ghibli",
#       "Studio Ghibli, Ajia-Do",
#       "Studio Ghibli, Polygon Pictures",
#       "Studio Gokumi",
#       "Studio Gokumi, AXsiZ",
#       "Studio Hibari",
#       "Studio Hibari, Grouper Productions",
#       "Studio Hibari, Production Reed",
#       "Studio Hokiboshi",
#       "Studio Jam",
#       "Studio Junio",
#       "Studio Junio, Annapuru",
#       "Studio Kafka",
#       "Studio Kai",
#       "Studio Kelmadick",
#       "Studio Khronos",
#       "Studio Kikan",
#       "Studio Korumi",
#       "Studio Kyuuma, Studio Kikan, Azeta Pictures",
#       "Studio LAN",
#       "Studio Live",
#       "Studio M2",
#       "Studio Matrix",
#       "Studio Meditation With a Pencil",
#       "Studio Moriken",
#       "Studio Nue",
#       "Studio OX",
#       "Studio Pierrot",
#       "Studio Pierrot, AIC ASTA",
#       "Studio Pierrot, Ajia-Do",
#       "Studio Pierrot, Arms",
#       "Studio Pierrot, D.A.S.T.",
#       "Studio Pierrot, David Production",
#       "Studio Pierrot, Gallop",
#       "Studio Pierrot, Kyoto Animation",
#       "Studio Pierrot, Pierrot Plus",
#       "Studio Pierrot, Studio Deen",
#       "Studio Pierrot, Studio Hibari",
#       "Studio Ponoc",
#       "Studio Ppuri",
#       "Studio PuYUKAI",
#       "Studio Rikka",
#       "Studio Rikka, Purple Cow Studio Japan",
#       "Studio Sign",
#       "Studio Signal",
#       "Studio Signpost",
#       "Studio Take Off",
#       "Studio UGOKI",
#       "Studio Unicorn",
#       "Studio Unicorn, Hiro Media",
#       "Studio VOLN",
#       "Studio VOLN, Studio M2",
#       "Studio W.Baba, P.I.C.S.",
#       "Studio Wombat",
#       "Studio World",
#       "Studio Z5, Studio March",
#       "Studio Zealot",
#       "Studio Zero",
#       "Studio Zero, Tokyo Movie",
#       "Studio elle, l-a-unch\u30fbBOX",
#       "Studio! Cucuri",
#       "Sublimation",
#       "Success Corp., Dangun Pictures",
#       "Sugar Boy, Blue Cat",
#       "Suiseisha",
#       "Sunrise",
#       "Sunrise Beyond",
#       "Sunrise, Ascension",
#       "Sunrise, Bandai Namco Pictures",
#       "Sunrise, Bandai Namco Pictures, XFLAG",
#       "Sunrise, Bandai Spirits",
#       "Sunrise, Bandai Visual",
#       "Sunrise, Dongwoo A&E",
#       "Sunrise, Kino Production",
#       "Sunrise, Nakamura Production",
#       "Sunrise, Production Reed",
#       "Sunrise, Sanrio",
#       "Sunrise, Studio Deen",
#       "Sunrise, Studio Hibari",
#       "Sunrise, Telecom Animation Film",
#       "Sunrise, The Answer Studio",
#       "Sunrise, Toei Animation",
#       "Sunwoo Entertainment",
#       "Super Normal Studio",
#       "Suspenders",
#       "Suzuki Mirano",
#       "SynergySP",
#       "SynergySP, Shin-Ei Animation",
#       "T-Rex",
#       "T.P.O",
#       "TAKI Corporation",
#       "TANOsim",
#       "TMS Entertainment",
#       "TMS Entertainment, 3xCube",
#       "TMS Entertainment, DLE",
#       "TMS Entertainment, Echoes",
#       "TMS Entertainment, Gathering",
#       "TMS Entertainment, Jinnis Animation Studios",
#       "TMS Entertainment, Marza Animation Planet",
#       "TMS Entertainment, Shin-Ei Animation",
#       "TMS Entertainment, Studio Comet",
#       "TMS Entertainment, Telecom Animation Film",
#       "TMS Entertainment, Tezuka Productions",
#       "TMS Entertainment, Tokyo Kids, Minami Machi Bugyousho",
#       "TNK",
#       "TNK, Kinema Citrus",
#       "TNK, Production Reed",
#       "TNK, Zero-G",
#       "TOHO animation",
#       "TROYCA",
#       "TUBA",
#       "TYMOTE",
#       "TYMOTE, Spoon",
#       "TYO Animations",
#       "TYO Animations, LIDENFILMS",
#       "Takahashi Studio, Suna Kouhou",
#       "Tama Production",
#       "Tamura Shigeru Studio",
#       "Taomee",
#       "Tatsunoko Production",
#       "Tatsunoko Production, 10Gauge",
#       "Tatsunoko Production, CoMix Wave Films, FOREST Hunting One",
#       "Tatsunoko Production, Dongwoo A&E",
#       "Tatsunoko Production, Eiken",
#       "Tatsunoko Production, Ordet",
#       "Tatsunoko Production, Production Reed, Asahi Production",
#       "Tatsunoko Production, Studio World",
#       "Tatsunoko Production, SynergySP",
#       "Tatsunoko Production, SynergySP, Seven",
#       "Tatsunoko Production, Tama Production",
#       "Team TillDawn",
#       "Team YokkyuFuman",
#       "Tear Studio",
#       "Teatro Nishi Tokyo Studio",
#       "Tecarat",
#       "Tele-Cartoon Japan",
#       "Telecom Animation Film",
#       "Telecom Animation Film, Graphinica",
#       "Telecom Animation Film, Shirogumi",
#       "Telescreen",
#       "Tencent Animation & Comics",
#       "Tencent Penguin Pictures",
#       "Tencent Penguin Pictures, Fenz",
#       "Tengu Kobo",
#       "Tezuka Productions",
#       "Tezuka Productions, MAPPA",
#       "Tezuka Productions, Okuruto Noboru",
#       "Tezuka Productions, Toho",
#       "The Answer Studio",
#       "Think Corporation",
#       "Three-d",
#       "Thundray",
#       "Toei Animation",
#       "Toei Animation, Bridge",
#       "Toei Animation, Daewon Media",
#       "Toei Animation, Gallop",
#       "Toei Animation, Production Reed",
#       "Toei Animation, Studio Deen",
#       "Toei Animation, Studio Nue",
#       "Toei Animation, Studio World",
#       "Toei Animation, Tatsunoko Production",
#       "Toei Video",
#       "Toho Interactive Animation",
#       "Tohokushinsha Film Corporation",
#       "Tokyo Kids",
#       "Tokyo Kids, Minami Machi Bugyousho",
#       "Tokyo Media Connections",
#       "Tokyo Movie Shinsha",
#       "Tokyo Movie Shinsha, Filmlink International",
#       "Tomason",
#       "Tomovies",
#       "Tomoyasu Murata Company",
#       "Tong Ming Xuan",
#       "Tonko House",
#       "Topcraft",
#       "Trans Arts",
#       "TriF Studio",
#       "Triangle Staff",
#       "Triangle Staff, Studio Wombat",
#       "Triangle Staff, animate Film",
#       "Trigger",
#       "Trigger, dwarf",
#       "Trinet Entertainment",
#       "Trinet Entertainment, Picture Magic",
#       "Trinet Entertainment, Studio Hibari",
#       "Trinet Entertainment, Studio Kyuuma",
#       "Triple X",
#       "Tsuchida Productions",
#       "Tsukimidou",
#       "Twilight Studio",
#       "Twin Engine",
#       "Typhoon Graphics",
#       "Typhoon Graphics, StoryRiders Co. Ltd.",
#       "UWAN Pictures",
#       "Unknown",
#       "Urban Product",
#       "Urban Product, UWAN Pictures",
#       "Usagi Ou, Studio Nanahoshi",
#       "Vasoon Animation",
#       "Vega Entertainment",
#       "Venet",
#       "View Works",
#       "Visual 80",
#       "Visual 80, Telescreen",
#       "Visual Flight",
#       "W+K Tokyo",
#       "W-Toon Studio",
#       "W-Toon Studio, DMM.futureworks",
#       "WAO World",
#       "WAO World, GEMBA",
#       "WAO World, MooGoo",
#       "WAO World, Studio Live",
#       "Wawayu Animation",
#       "Wei Chuang Jiang Xin",
#       "White Fox",
#       "Will Palette",
#       "Wit Studio",
#       "Wit Studio, Square Enix Visual Works",
#       "Wolf Smoke Studio",
#       "Wolfsbane",
#       "Xebec",
#       "Xebec, AIC",
#       "Xebec, Genco, Triangle Staff",
#       "Xebec, Group TAC",
#       "Xebec, I.Gzwei",
#       "Xebec, Issen",
#       "Xebec, Kanaban Graphics",
#       "Xebec, OLM",
#       "Xebec, Production Reed",
#       "Y.O.U.C",
#       "YHKT Entertainment",
#       "Yamamura Animation, Inc.",
#       "Yamato Works",
#       "Yaoyorozu",
#       "Yi Chen Animation",
#       "Yokohama Animation Lab",
#       "Yokohama Animation Lab, Arvo Animation",
#       "Yostar Pictures",
#       "Yostar Pictures, CANDY BOX",
#       "Youmex",
#       "Yumeta Company",
#       "Yumeta Company, Graphinica",
#       "ZIZ Entertainment (ZIZ)",
#       "Zero-G",
#       "Zero-G Room",
#       "Zexcs",
#       "Zexcs, Studio A-CAT",
#       "animate Film",
#       "animate Film, Studio Kikan",
#       "animate Film, Visual 80",
#       "domerica",
#       "drop",
#       "dwarf",
#       "dwarf, TYO",
#       "feel.",
#       "feel., Assez Finaud Fabric",
#       "feel., PRA",
#       "feel., Zexcs",
#       "feel., Zexcs, Assez Finaud Fabric",
#       "helo.inc",
#       "iDRAGONS Creative Studio",
#       "ixtl, LIDENFILMS",
#       "monofilmo",
#       "pH Studio",
#       "production doA",
#       "ufotable",
#       "ufotable, feel., Studio Flag"
#     ],
#     "details": {
#       "value_counts": [
#         {
#           "value": "10Gauge",
#           "count": 3
#         },
#         {
#           "value": "10Gauge, Studio DURIAN",
#           "count": 1
#         },
#         {
#           "value": "2:10 AM Animation",
#           "count": 6
#         },
#         {
#           "value": "8bit",
#           "count": 44
#         },
#         {
#           "value": "A-1 Pictures",
#           "count": 192
#         },
#         {
#           "value": "A-1 Pictures, Bridge",
#           "count": 2
#         },
#         {
#           "value": "A-1 Pictures, Bridge, CloverWorks",
#           "count": 1
#         },
#         {
#           "value": "A-1 Pictures, Lapin Track",
#           "count": 1
#         },
#         {
#           "value": "A-1 Pictures, Ordet",
#           "count": 3
#         },
#         {
#           "value": "A-1 Pictures, TROYCA",
#           "count": 3
#         },
#         {
#           "value": "A-1 Pictures, Trigger, CloverWorks",
#           "count": 1
#         },
#         {
#           "value": "A-Line",
#           "count": 1
#         },
#         {
#           "value": "A-Real",
#           "count": 3
#         },
#         {
#           "value": "A.C.G.T.",
#           "count": 28
#         },
#         {
#           "value": "ACC Production",
#           "count": 2
#         },
#         {
#           "value": "AIC",
#           "count": 121
#         },
#         {
#           "value": "AIC ASTA",
#           "count": 25
#         },
#         {
#           "value": "AIC Build",
#           "count": 10
#         },
#         {
#           "value": "AIC Classic",
#           "count": 7
#         },
#         {
#           "value": "AIC Frontier",
#           "count": 3
#         },
#         {
#           "value": "AIC PLUS+",
#           "count": 18
#         },
#         {
#           "value": "AIC Spirits",
#           "count": 9
#         },
#         {
#           "value": "AIC Spirits, Asread",
#           "count": 1
#         },
#         {
#           "value": "AIC Spirits, BeSTACK",
#           "count": 2
#         },
#         {
#           "value": "AIC Spirits, Digital Frontier",
#           "count": 1
#         },
#         {
#           "value": "AIC Spirits, Group TAC",
#           "count": 1
#         },
#         {
#           "value": "AIC Takarazuka",
#           "count": 1
#         },
#         {
#           "value": "AIC, APPP",
#           "count": 1
#         },
#         {
#           "value": "AIC, Artmic",
#           "count": 5
#         },
#         {
#           "value": "AIC, Artmic, Darts",
#           "count": 1
#         },
#         {
#           "value": "AIC, Artmic, animate Film",
#           "count": 4
#         },
#         {
#           "value": "AIC, Darts",
#           "count": 1
#         },
#         {
#           "value": "AIC, Magic Bus, Ashi Production",
#           "count": 1
#         },
#         {
#           "value": "AIC, Remic",
#           "count": 1
#         },
#         {
#           "value": "AIC, Studio Hakk",
#           "count": 1
#         },
#         {
#           "value": "AIC, Studio Kyuuma",
#           "count": 1
#         },
#         {
#           "value": "AIC, animate Film",
#           "count": 2
#         },
#         {
#           "value": "APPP",
#           "count": 17
#         },
#         {
#           "value": "AQUA ARIS",
#           "count": 13
#         },
#         {
#           "value": "ASK Animation Studio",
#           "count": 5
#         },
#         {
#           "value": "AT-2",
#           "count": 15
#         },
#         {
#           "value": "AXsiZ",
#           "count": 2
#         },
#         {
#           "value": "Academy Productions",
#           "count": 1
#         },
#         {
#           "value": "Acca effe, Giga Production",
#           "count": 4
#         },
#         {
#           "value": "Actas",
#           "count": 39
#         },
#         {
#           "value": "Actas, Bee Media",
#           "count": 1
#         },
#         {
#           "value": "Actas, Brain's Base",
#           "count": 1
#         },
#         {
#           "value": "Actas, Production Reed",
#           "count": 1
#         },
#         {
#           "value": "Actas, Studio 3Hz",
#           "count": 3
#         },
#         {
#           "value": "Actas, SynergySP",
#           "count": 2
#         },
#         {
#           "value": "Actas, TMS Entertainment",
#           "count": 1
#         },
#         {
#           "value": "Agent 21",
#           "count": 3
#         },
#         {
#           "value": "Ajia-Do",
#           "count": 37
#         },
#         {
#           "value": "Ajia-Do, Bandai Namco Pictures",
#           "count": 1
#         },
#         {
#           "value": "Ajia-Do, Group TAC",
#           "count": 1
#         },
#         {
#           "value": "Ajia-Do, Studio Deen",
#           "count": 1
#         },
#         {
#           "value": "Ajia-Do, TMS Entertainment",
#           "count": 1
#         },
#         {
#           "value": "Akatsuki",
#           "count": 3
#         },
#         {
#           "value": "Albacrow",
#           "count": 1
#         },
#         {
#           "value": "An DerCen",
#           "count": 2
#         },
#         {
#           "value": "Anima",
#           "count": 3
#         },
#         {
#           "value": "Anima&Co.",
#           "count": 2
#         },
#         {
#           "value": "Anima, Dynamo Pictures",
#           "count": 1
#         },
#         {
#           "value": "Anima, ILCA",
#           "count": 1
#         },
#         {
#           "value": "Animaruya",
#           "count": 1
#         },
#         {
#           "value": "Animation 21",
#           "count": 1
#         },
#         {
#           "value": "Animation Planet",
#           "count": 1
#         },
#         {
#           "value": "Animation Staff Room",
#           "count": 3
#         },
#         {
#           "value": "Anime Antenna Iinkai",
#           "count": 3
#         },
#         {
#           "value": "Anime R",
#           "count": 1
#         },
#         {
#           "value": "Anime R, Aubec",
#           "count": 1
#         },
#         {
#           "value": "Annapuru",
#           "count": 1
#         },
#         {
#           "value": "Anpro",
#           "count": 2
#         },
#         {
#           "value": "Anpro, teamKG",
#           "count": 1
#         },
#         {
#           "value": "Arcs Create",
#           "count": 1
#         },
#         {
#           "value": "Arcturus",
#           "count": 1
#         },
#         {
#           "value": "Ark",
#           "count": 1
#         },
#         {
#           "value": "Arms",
#           "count": 74
#         },
#         {
#           "value": "Arms, Asread",
#           "count": 1
#         },
#         {
#           "value": "Arms, Studio Kikan",
#           "count": 1
#         },
#         {
#           "value": "Arms, TNK",
#           "count": 2
#         },
#         {
#           "value": "Artland",
#           "count": 34
#         },
#         {
#           "value": "Artland, AIC, Artmic",
#           "count": 1
#         },
#         {
#           "value": "Artland, Hoods Entertainment",
#           "count": 1
#         },
#         {
#           "value": "Artland, Madhouse",
#           "count": 1
#         },
#         {
#           "value": "Artland, Magic Bus",
#           "count": 2
#         },
#         {
#           "value": "Artland, Nippon Animation",
#           "count": 1
#         },
#         {
#           "value": "Artland, TNK",
#           "count": 4
#         },
#         {
#           "value": "Artland, Tatsunoko Production",
#           "count": 1
#         },
#         {
#           "value": "Artmic",
#           "count": 4
#         },
#         {
#           "value": "Artmic, animate Film",
#           "count": 1
#         },
#         {
#           "value": "Arvo Animation",
#           "count": 2
#         },
#         {
#           "value": "Asahi Production",
#           "count": 32
#         },
#         {
#           "value": "Asahi Production, Rising Force",
#           "count": 1
#         },
#         {
#           "value": "Asahi Production, Shochiku Animation Institute",
#           "count": 1
#         },
#         {
#           "value": "Asahi Production, Success Corp.",
#           "count": 1
#         },
#         {
#           "value": "Asatsu DK, Sunrise Beyond",
#           "count": 1
#         },
#         {
#           "value": "Ascension",
#           "count": 5
#         },
#         {
#           "value": "Ascension, Creators in Pack, Zero-G",
#           "count": 1
#         },
#         {
#           "value": "Ashi Production",
#           "count": 8
#         },
#         {
#           "value": "Asread",
#           "count": 19
#         },
#         {
#           "value": "Asread, Tear Studio",
#           "count": 1
#         },
#         {
#           "value": "Asread, White Fox",
#           "count": 2
#         },
#         {
#           "value": "Asura Film",
#           "count": 4
#         },
#         {
#           "value": "Aubec",
#           "count": 3
#         },
#         {
#           "value": "Automatic Flowers Studio",
#           "count": 1
#         },
#         {
#           "value": "Avex Pictures, production doA",
#           "count": 1
#         },
#         {
#           "value": "Azeta Pictures",
#           "count": 1
#         },
#         {
#           "value": "B&T",
#           "count": 2
#         },
#         {
#           "value": "B.CMAY PICTURES",
#           "count": 16
#         },
#         {
#           "value": "B.CMAY PICTURES, Colored-Pencil Animation Design",
#           "count": 1
#         },
#         {
#           "value": "BOOTLEG",
#           "count": 1
#         },
#         {
#           "value": "BUILD DREAM",
#           "count": 4
#         },
#         {
#           "value": "BYMENT",
#           "count": 3
#         },
#         {
#           "value": "Bakken Record",
#           "count": 2
#         },
#         {
#           "value": "Bandai Namco Pictures",
#           "count": 37
#         },
#         {
#           "value": "Barnum Studio, Project No.9",
#           "count": 3
#         },
#         {
#           "value": "Barnum Studio, Project No.9, Studio Blanc",
#           "count": 1
#         },
#         {
#           "value": "Barnum Studio, SILVER LINK., Connect",
#           "count": 1
#         },
#         {
#           "value": "Bee Media",
#           "count": 2
#         },
#         {
#           "value": "Bee Media, 81 Produce",
#           "count": 1
#         },
#         {
#           "value": "Bee Media, Code",
#           "count": 1
#         },
#         {
#           "value": "Bee Media, Studio Signal",
#           "count": 1
#         },
#         {
#           "value": "Bee Train",
#           "count": 24
#         },
#         {
#           "value": "Bee Train, Cookie Jar Entertainment",
#           "count": 1
#         },
#         {
#           "value": "Bee Train, Production I.G, Madhouse, Studio 4\u00b0C",
#           "count": 1
#         },
#         {
#           "value": "Bee Train, Xebec",
#           "count": 1
#         },
#         {
#           "value": "Beijing Rocen Digital",
#           "count": 4
#         },
#         {
#           "value": "Bibury Animation Studios",
#           "count": 5
#         },
#         {
#           "value": "Big Bang",
#           "count": 1
#         },
#         {
#           "value": "BigFireBird Animation",
#           "count": 4
#         },
#         {
#           "value": "Blade",
#           "count": 2
#         },
#         {
#           "value": "Blade, Thundray",
#           "count": 4
#         },
#         {
#           "value": "Blue Cat",
#           "count": 5
#         },
#         {
#           "value": "Bones",
#           "count": 127
#         },
#         {
#           "value": "Bones, Kinema Citrus",
#           "count": 3
#         },
#         {
#           "value": "Bones, Nomad",
#           "count": 1
#         },
#         {
#           "value": "Bones, Orange",
#           "count": 1
#         },
#         {
#           "value": "Bones, Production I.G, Studio 4\u00b0C, Toei Animation",
#           "count": 1
#         },
#         {
#           "value": "Bones, Production Reed",
#           "count": 1
#         },
#         {
#           "value": "Bones, Sanrio",
#           "count": 1
#         },
#         {
#           "value": "Bones, Sunrise",
#           "count": 1
#         },
#         {
#           "value": "Bones, Telecom Animation Film",
#           "count": 1
#         },
#         {
#           "value": "Bouncy",
#           "count": 5
#         },
#         {
#           "value": "Boyan Pictures",
#           "count": 1
#         },
#         {
#           "value": "Brain's Base",
#           "count": 86
#         },
#         {
#           "value": "Brain's Base, Marvy Jack",
#           "count": 3
#         },
#         {
#           "value": "Brain's Base, Platinum Vision",
#           "count": 1
#         },
#         {
#           "value": "Brain's Base, Shogakukan Music & Digital Entertainment",
#           "count": 2
#         },
#         {
#           "value": "Brain's Base, Studio A-CAT",
#           "count": 1
#         },
#         {
#           "value": "BreakBottle",
#           "count": 6
#         },
#         {
#           "value": "Bridge",
#           "count": 14
#         },
#         {
#           "value": "Bridge, Husio Studio",
#           "count": 3
#         },
#         {
#           "value": "Brio Animation",
#           "count": 1
#         },
#         {
#           "value": "Buemon",
#           "count": 2
#         },
#         {
#           "value": "C-Station",
#           "count": 14
#         },
#         {
#           "value": "C2C",
#           "count": 11
#         },
#         {
#           "value": "C2C, Lay-duce",
#           "count": 1
#         },
#         {
#           "value": "CG Year",
#           "count": 8
#         },
#         {
#           "value": "CLAP",
#           "count": 4
#         },
#         {
#           "value": "CUCURI, Digital Network Animation",
#           "count": 1
#         },
#         {
#           "value": "Calf Studio",
#           "count": 1
#         },
#         {
#           "value": "Chaos Project",
#           "count": 5
#         },
#         {
#           "value": "Chaos Project, GANSIS",
#           "count": 1
#         },
#         {
#           "value": "Charaction",
#           "count": 6
#         },
#         {
#           "value": "Children's Playground Entertainment",
#           "count": 3
#         },
#         {
#           "value": "Chippai",
#           "count": 1
#         },
#         {
#           "value": "Chiptune",
#           "count": 1
#         },
#         {
#           "value": "ChuChu",
#           "count": 3
#         },
#         {
#           "value": "Circle Tribute",
#           "count": 2
#         },
#         {
#           "value": "CloverWorks",
#           "count": 26
#         },
#         {
#           "value": "CoMix Wave Films",
#           "count": 19
#         },
#         {
#           "value": "CoMix Wave Films, FOREST Hunting One",
#           "count": 1
#         },
#         {
#           "value": "Coastline Animation Studio",
#           "count": 1
#         },
#         {
#           "value": "Collaboration Works",
#           "count": 13
#         },
#         {
#           "value": "Composition Inc.",
#           "count": 1
#         },
#         {
#           "value": "Congzhuo Animation",
#           "count": 1
#         },
#         {
#           "value": "Connect",
#           "count": 7
#         },
#         {
#           "value": "Craftar Studios",
#           "count": 3
#         },
#         {
#           "value": "Creators Dot Com",
#           "count": 2
#         },
#         {
#           "value": "Creators in Pack",
#           "count": 17
#         },
#         {
#           "value": "Creators in Pack, LEVELS",
#           "count": 1
#         },
#         {
#           "value": "Creators in Pack, Namu Animation",
#           "count": 1
#         },
#         {
#           "value": "Creators in Pack, Saetta",
#           "count": 2
#         },
#         {
#           "value": "Creators in Pack, Studio Lings",
#           "count": 1
#         },
#         {
#           "value": "Creatures Inc.",
#           "count": 2
#         },
#         {
#           "value": "CyberConnect2",
#           "count": 1
#         },
#         {
#           "value": "Cyclone Graphics",
#           "count": 1
#         },
#         {
#           "value": "CygamesPictures",
#           "count": 4
#         },
#         {
#           "value": "D & D Pictures",
#           "count": 2
#         },
#         {
#           "value": "D.A.S.T.",
#           "count": 1
#         },
#         {
#           "value": "DAX Production",
#           "count": 2
#         },
#         {
#           "value": "DLE",
#           "count": 133
#         },
#         {
#           "value": "DMM pictures",
#           "count": 2
#         },
#         {
#           "value": "DR Movie",
#           "count": 2
#         },
#         {
#           "value": "Daewon Media",
#           "count": 6
#         },
#         {
#           "value": "Dai-Ichi Douga",
#           "count": 1
#         },
#         {
#           "value": "Dai-Ichi Douga, Dongyang Animation",
#           "count": 1
#         },
#         {
#           "value": "Dancing CG Studio",
#           "count": 1
#         },
#         {
#           "value": "DandeLion Animation Studio",
#           "count": 3
#         },
#         {
#           "value": "Darts",
#           "count": 1
#         },
#         {
#           "value": "Daume",
#           "count": 28
#         },
#         {
#           "value": "David Production",
#           "count": 35
#         },
#         {
#           "value": "Decovocal",
#           "count": 1
#         },
#         {
#           "value": "Digital Frontier",
#           "count": 6
#         },
#         {
#           "value": "Digital Media Lab",
#           "count": 2
#         },
#         {
#           "value": "Digital Network Animation",
#           "count": 1
#         },
#         {
#           "value": "Diomed\u00e9a",
#           "count": 49
#         },
#         {
#           "value": "Diomed\u00e9a, Studio Blanc",
#           "count": 2
#         },
#         {
#           "value": "Directions",
#           "count": 1
#         },
#         {
#           "value": "Djinn Power",
#           "count": 1
#         },
#         {
#           "value": "Doga Kobo",
#           "count": 82
#         },
#         {
#           "value": "Doga Kobo, Orange",
#           "count": 1
#         },
#         {
#           "value": "Dongwoo A&E",
#           "count": 3
#         },
#         {
#           "value": "Drive",
#           "count": 2
#         },
#         {
#           "value": "Durufix",
#           "count": 1
#         },
#         {
#           "value": "Dwango, LIDENFILMS",
#           "count": 1
#         },
#         {
#           "value": "Dynamic Planning",
#           "count": 1
#         },
#         {
#           "value": "Dynamo Pictures",
#           "count": 4
#         },
#         {
#           "value": "E&G Films",
#           "count": 9
#         },
#         {
#           "value": "EDGE",
#           "count": 1
#         },
#         {
#           "value": "EKACHI EPILKA",
#           "count": 2
#         },
#         {
#           "value": "EMT Squared",
#           "count": 17
#         },
#         {
#           "value": "ENGI",
#           "count": 4
#         },
#         {
#           "value": "Echo",
#           "count": 1
#         },
#         {
#           "value": "Echoes",
#           "count": 5
#         },
#         {
#           "value": "Egg",
#           "count": 4
#         },
#         {
#           "value": "Eiken",
#           "count": 36
#         },
#         {
#           "value": "Eiken, Magic Bus",
#           "count": 1
#         },
#         {
#           "value": "Eiken, Studio Live",
#           "count": 2
#         },
#         {
#           "value": "Eiken, TYO Animations",
# ...
#           "count": 1
#         },
#         {
#           "value": "Sunrise, The Answer Studio",
#           "count": 1
#         },
#         {
#           "value": "Sunrise, Toei Animation",
#           "count": 4
#         },
#         {
#           "value": "Sunwoo Entertainment",
#           "count": 1
#         },
#         {
#           "value": "Super Normal Studio",
#           "count": 3
#         },
#         {
#           "value": "Suspenders",
#           "count": 1
#         },
#         {
#           "value": "Suzuki Mirano",
#           "count": 15
#         },
#         {
#           "value": "SynergySP",
#           "count": 36
#         },
#         {
#           "value": "SynergySP, Shin-Ei Animation",
#           "count": 1
#         },
#         {
#           "value": "T-Rex",
#           "count": 48
#         },
#         {
#           "value": "T.P.O",
#           "count": 1
#         },
#         {
#           "value": "TAKI Corporation",
#           "count": 3
#         },
#         {
#           "value": "TANOsim",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment",
#           "count": 266
#         },
#         {
#           "value": "TMS Entertainment, 3xCube",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment, DLE",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment, Echoes",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment, Gathering",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment, Jinnis Animation Studios",
#           "count": 2
#         },
#         {
#           "value": "TMS Entertainment, Marza Animation Planet",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment, Shin-Ei Animation",
#           "count": 2
#         },
#         {
#           "value": "TMS Entertainment, Studio Comet",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment, Telecom Animation Film",
#           "count": 2
#         },
#         {
#           "value": "TMS Entertainment, Tezuka Productions",
#           "count": 1
#         },
#         {
#           "value": "TMS Entertainment, Tokyo Kids, Minami Machi Bugyousho",
#           "count": 1
#         },
#         {
#           "value": "TNK",
#           "count": 42
#         },
#         {
#           "value": "TNK, Kinema Citrus",
#           "count": 1
#         },
#         {
#           "value": "TNK, Production Reed",
#           "count": 1
#         },
#         {
#           "value": "TNK, Zero-G",
#           "count": 1
#         },
#         {
#           "value": "TOHO animation",
#           "count": 1
#         },
#         {
#           "value": "TROYCA",
#           "count": 11
#         },
#         {
#           "value": "TUBA",
#           "count": 2
#         },
#         {
#           "value": "TYMOTE",
#           "count": 1
#         },
#         {
#           "value": "TYMOTE, Spoon",
#           "count": 1
#         },
#         {
#           "value": "TYO Animations",
#           "count": 27
#         },
#         {
#           "value": "TYO Animations, LIDENFILMS",
#           "count": 1
#         },
#         {
#           "value": "Takahashi Studio, Suna Kouhou",
#           "count": 1
#         },
#         {
#           "value": "Tama Production",
#           "count": 2
#         },
#         {
#           "value": "Tamura Shigeru Studio",
#           "count": 1
#         },
#         {
#           "value": "Taomee",
#           "count": 1
#         },
#         {
#           "value": "Tatsunoko Production",
#           "count": 138
#         },
#         {
#           "value": "Tatsunoko Production, 10Gauge",
#           "count": 1
#         },
#         {
#           "value": "Tatsunoko Production, CoMix Wave Films, FOREST Hunting One",
#           "count": 1
#         },
#         {
#           "value": "Tatsunoko Production, Dongwoo A&E",
#           "count": 6
#         },
#         {
#           "value": "Tatsunoko Production, Eiken",
#           "count": 1
#         },
#         {
#           "value": "Tatsunoko Production, Ordet",
#           "count": 2
#         },
#         {
#           "value": "Tatsunoko Production, Production Reed, Asahi Production",
#           "count": 1
#         },
#         {
#           "value": "Tatsunoko Production, Studio World",
#           "count": 2
#         },
#         {
#           "value": "Tatsunoko Production, SynergySP",
#           "count": 3
#         },
#         {
#           "value": "Tatsunoko Production, SynergySP, Seven",
#           "count": 1
#         },
#         {
#           "value": "Tatsunoko Production, Tama Production",
#           "count": 1
#         },
#         {
#           "value": "Team TillDawn",
#           "count": 1
#         },
#         {
#           "value": "Team YokkyuFuman",
#           "count": 2
#         },
#         {
#           "value": "Tear Studio",
#           "count": 4
#         },
#         {
#           "value": "Teatro Nishi Tokyo Studio",
#           "count": 1
#         },
#         {
#           "value": "Tecarat",
#           "count": 2
#         },
#         {
#           "value": "Tele-Cartoon Japan",
#           "count": 1
#         },
#         {
#           "value": "Telecom Animation Film",
#           "count": 25
#         },
#         {
#           "value": "Telecom Animation Film, Graphinica",
#           "count": 4
#         },
#         {
#           "value": "Telecom Animation Film, Shirogumi",
#           "count": 2
#         },
#         {
#           "value": "Telescreen",
#           "count": 7
#         },
#         {
#           "value": "Tencent Animation & Comics",
#           "count": 2
#         },
#         {
#           "value": "Tencent Penguin Pictures",
#           "count": 1
#         },
#         {
#           "value": "Tencent Penguin Pictures, Fenz",
#           "count": 2
#         },
#         {
#           "value": "Tengu Kobo",
#           "count": 2
#         },
#         {
#           "value": "Tezuka Productions",
#           "count": 35
#         },
#         {
#           "value": "Tezuka Productions, MAPPA",
#           "count": 2
#         },
#         {
#           "value": "Tezuka Productions, Okuruto Noboru",
#           "count": 1
#         },
#         {
#           "value": "Tezuka Productions, Toho",
#           "count": 1
#         },
#         {
#           "value": "The Answer Studio",
#           "count": 6
#         },
#         {
#           "value": "Think Corporation",
#           "count": 1
#         },
#         {
#           "value": "Three-d",
#           "count": 1
#         },
#         {
#           "value": "Thundray",
#           "count": 2
#         },
#         {
#           "value": "Toei Animation",
#           "count": 695
#         },
#         {
#           "value": "Toei Animation, Bridge",
#           "count": 1
#         },
#         {
#           "value": "Toei Animation, Daewon Media",
#           "count": 1
#         },
#         {
#           "value": "Toei Animation, Gallop",
#           "count": 2
#         },
#         {
#           "value": "Toei Animation, Production Reed",
#           "count": 2
#         },
#         {
#           "value": "Toei Animation, Studio Deen",
#           "count": 2
#         },
#         {
#           "value": "Toei Animation, Studio Nue",
#           "count": 1
#         },
#         {
#           "value": "Toei Animation, Studio World",
#           "count": 3
#         },
#         {
#           "value": "Toei Animation, Tatsunoko Production",
#           "count": 1
#         },
#         {
#           "value": "Toei Video",
#           "count": 1
#         },
#         {
#           "value": "Toho Interactive Animation",
#           "count": 1
#         },
#         {
#           "value": "Tohokushinsha Film Corporation",
#           "count": 1
#         },
#         {
#           "value": "Tokyo Kids",
#           "count": 8
#         },
#         {
#           "value": "Tokyo Kids, Minami Machi Bugyousho",
#           "count": 1
#         },
#         {
#           "value": "Tokyo Media Connections",
#           "count": 1
#         },
#         {
#           "value": "Tokyo Movie Shinsha",
#           "count": 44
#         },
#         {
#           "value": "Tokyo Movie Shinsha, Filmlink International",
#           "count": 1
#         },
#         {
#           "value": "Tomason",
#           "count": 3
#         },
#         {
#           "value": "Tomovies",
#           "count": 4
#         },
#         {
#           "value": "Tomoyasu Murata Company",
#           "count": 2
#         },
#         {
#           "value": "Tong Ming Xuan",
#           "count": 1
#         },
#         {
#           "value": "Tonko House",
#           "count": 2
#         },
#         {
#           "value": "Topcraft",
#           "count": 5
#         },
#         {
#           "value": "Trans Arts",
#           "count": 10
#         },
#         {
#           "value": "TriF Studio",
#           "count": 3
#         },
#         {
#           "value": "Triangle Staff",
#           "count": 17
#         },
#         {
#           "value": "Triangle Staff, Studio Wombat",
#           "count": 1
#         },
#         {
#           "value": "Triangle Staff, animate Film",
#           "count": 1
#         },
#         {
#           "value": "Trigger",
#           "count": 28
#         },
#         {
#           "value": "Trigger, dwarf",
#           "count": 1
#         },
#         {
#           "value": "Trinet Entertainment",
#           "count": 2
#         },
#         {
#           "value": "Trinet Entertainment, Picture Magic",
#           "count": 3
#         },
#         {
#           "value": "Trinet Entertainment, Studio Hibari",
#           "count": 1
#         },
#         {
#           "value": "Trinet Entertainment, Studio Kyuuma",
#           "count": 1
#         },
#         {
#           "value": "Triple X",
#           "count": 2
#         },
#         {
#           "value": "Tsuchida Productions",
#           "count": 3
#         },
#         {
#           "value": "Tsukimidou",
#           "count": 1
#         },
#         {
#           "value": "Twilight Studio",
#           "count": 1
#         },
#         {
#           "value": "Twin Engine",
#           "count": 2
#         },
#         {
#           "value": "Typhoon Graphics",
#           "count": 6
#         },
#         {
#           "value": "Typhoon Graphics, StoryRiders Co. Ltd.",
#           "count": 1
#         },
#         {
#           "value": "UWAN Pictures",
#           "count": 2
#         },
#         {
#           "value": "Unknown",
#           "count": 4912
#         },
#         {
#           "value": "Urban Product",
#           "count": 1
#         },
#         {
#           "value": "Urban Product, UWAN Pictures",
#           "count": 1
#         },
#         {
#           "value": "Usagi Ou, Studio Nanahoshi",
#           "count": 1
#         },
#         {
#           "value": "Vasoon Animation",
#           "count": 4
#         },
#         {
#           "value": "Vega Entertainment",
#           "count": 7
#         },
#         {
#           "value": "Venet",
#           "count": 3
#         },
#         {
#           "value": "View Works",
#           "count": 1
#         },
#         {
#           "value": "Visual 80",
#           "count": 3
#         },
#         {
#           "value": "Visual 80, Telescreen",
#           "count": 1
#         },
#         {
#           "value": "Visual Flight",
#           "count": 1
#         },
#         {
#           "value": "W+K Tokyo",
#           "count": 1
#         },
#         {
#           "value": "W-Toon Studio",
#           "count": 5
#         },
#         {
#           "value": "W-Toon Studio, DMM.futureworks",
#           "count": 9
#         },
#         {
#           "value": "WAO World",
#           "count": 6
#         },
#         {
#           "value": "WAO World, GEMBA",
#           "count": 1
#         },
#         {
#           "value": "WAO World, MooGoo",
#           "count": 2
#         },
#         {
#           "value": "WAO World, Studio Live",
#           "count": 1
#         },
#         {
#           "value": "Wawayu Animation",
#           "count": 4
#         },
#         {
#           "value": "Wei Chuang Jiang Xin",
#           "count": 1
#         },
#         {
#           "value": "White Fox",
#           "count": 39
#         },
#         {
#           "value": "Will Palette",
#           "count": 1
#         },
#         {
#           "value": "Wit Studio",
#           "count": 51
#         },
#         {
#           "value": "Wit Studio, Square Enix Visual Works",
#           "count": 1
#         },
#         {
#           "value": "Wolf Smoke Studio",
#           "count": 2
#         },
#         {
#           "value": "Wolfsbane",
#           "count": 1
#         },
#         {
#           "value": "Xebec",
#           "count": 114
#         },
#         {
#           "value": "Xebec, AIC",
#           "count": 1
#         },
#         {
#           "value": "Xebec, Genco, Triangle Staff",
#           "count": 1
#         },
#         {
#           "value": "Xebec, Group TAC",
#           "count": 1
#         },
#         {
#           "value": "Xebec, I.Gzwei",
#           "count": 3
#         },
#         {
#           "value": "Xebec, Issen",
#           "count": 4
#         },
#         {
#           "value": "Xebec, Kanaban Graphics",
#           "count": 1
#         },
#         {
#           "value": "Xebec, OLM",
#           "count": 9
#         },
#         {
#           "value": "Xebec, Production Reed",
#           "count": 1
#         },
#         {
#           "value": "Y.O.U.C",
#           "count": 16
#         },
#         {
#           "value": "YHKT Entertainment",
#           "count": 3
#         },
#         {
#           "value": "Yamamura Animation, Inc.",
#           "count": 4
#         },
#         {
#           "value": "Yamato Works",
#           "count": 1
#         },
#         {
#           "value": "Yaoyorozu",
#           "count": 9
#         },
#         {
#           "value": "Yi Chen Animation",
#           "count": 1
#         },
#         {
#           "value": "Yokohama Animation Lab",
#           "count": 8
#         },
#         {
#           "value": "Yokohama Animation Lab, Arvo Animation",
#           "count": 1
#         },
#         {
#           "value": "Yostar Pictures",
#           "count": 1
#         },
#         {
#           "value": "Yostar Pictures, CANDY BOX",
#           "count": 1
#         },
#         {
#           "value": "Youmex",
#           "count": 1
#         },
#         {
#           "value": "Yumeta Company",
#           "count": 15
#         },
#         {
#           "value": "Yumeta Company, Graphinica",
#           "count": 3
#         },
#         {
#           "value": "ZIZ Entertainment (ZIZ)",
#           "count": 1
#         },
#         {
#           "value": "Zero-G",
#           "count": 18
#         },
#         {
#           "value": "Zero-G Room",
#           "count": 6
#         },
#         {
#           "value": "Zexcs",
#           "count": 63
#         },
#         {
#           "value": "Zexcs, Studio A-CAT",
#           "count": 2
#         },
#         {
#           "value": "animate Film",
#           "count": 16
#         },
#         {
#           "value": "animate Film, Studio Kikan",
#           "count": 1
#         },
#         {
#           "value": "animate Film, Visual 80",
#           "count": 1
#         },
#         {
#           "value": "domerica",
#           "count": 2
#         },
#         {
#           "value": "drop",
#           "count": 2
#         },
#         {
#           "value": "dwarf",
#           "count": 6
#         },
#         {
#           "value": "dwarf, TYO",
#           "count": 1
#         },
#         {
#           "value": "feel.",
#           "count": 55
#         },
#         {
#           "value": "feel., Assez Finaud Fabric",
#           "count": 2
#         },
#         {
#           "value": "feel., PRA",
#           "count": 1
#         },
#         {
#           "value": "feel., Zexcs",
#           "count": 5
#         },
#         {
#           "value": "feel., Zexcs, Assez Finaud Fabric",
#           "count": 1
#         },
#         {
#           "value": "helo.inc",
#           "count": 1
#         },
#         {
#           "value": "iDRAGONS Creative Studio",
#           "count": 1
#         },
#         {
#           "value": "ixtl, LIDENFILMS",
#           "count": 1
#         },
#         {
#           "value": "monofilmo",
#           "count": 2
#         },
#         {
#           "value": "pH Studio",
#           "count": 1
#         },
#         {
#           "value": "production doA",
#           "count": 3
#         },
#         {
#           "value": "ufotable",
#           "count": 63
#         },
#         {
#           "value": "ufotable, feel., Studio Flag",
#           "count": 1
#         }
#       ]
#     }
#   },
#   "meta": {},
#   "exception_info": {
#     "raised_exception": false,
#     "exception_traceback": null,
#     "exception_message": null
#   }
# }

# %% [markdown]
# ### Save into Expectation Suite

# %%
validator.save_expectation_suite(discard_failed_expectations=False)

# %% [markdown]
# ### Build Data Docs

# %%
context.build_data_docs()
# Out:
# {'local_site': 'file://c:\\FTDS\\MS\\p2-ftds012-hck-m3-samueltatsu\\gx\\uncommitted/data_docs/local_site/index.html'}
